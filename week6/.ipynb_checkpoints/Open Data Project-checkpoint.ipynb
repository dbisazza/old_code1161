# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import math
import gzip
from math import radians, cos, sin, asin, sqrt
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point
import matplotlib.patches as mpatches
import matplotlib.lines as mlines

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = matplotlib.rcParams.copy()

# %%
if os.path.isfile("listings.csv"):
    filepath = "listings.csv"
    print "loading from file"
else:
    filepath = "http://data.insideairbnb.com/australia/nsw/sydney/2017-04-03/visualisations/listings.csv"
    print "loading from the internet"
    

sydData = pd.read_csv(filepath)
print "done"
# Out:
# loading from the internet
# done

# %%
sydData.columns
# Out:
# Index([u'id', u'name', u'host_id', u'host_name', u'neighbourhood_group',
#        u'neighbourhood', u'latitude', u'longitude', u'room_type', u'price',
#        u'minimum_nights', u'number_of_reviews', u'last_review',
#        u'reviews_per_month', u'calculated_host_listings_count',
#        u'availability_365'],
#       dtype='object')

# %%
def DistanceCBD(lat, lon, cbdlat, cbdlon):
    cbdlon, cbdlat, lon, lat = map(radians, [cbdlon, cbdlat, lon, lat])
    dlon = lon - cbdlon 
    dlat = lat - cbdlat
    a = sin(dlat/2)**2 + cos(cbdlat) * cos(lat) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    km = 6367 * c
    return km

# %%
def convertGeometry(lat, lon):
    return Point(lon, lat)

# %%
distance_cbd = []
sydneylat = -33.8708
sydneylon = 151.2073
for x in range(0, len(sydData)):
    lat = sydData["latitude"].iloc[x]
    lon = sydData["longitude"].iloc[x]
    distance_cbd.append(DistanceCBD(lat, lon, sydneylat, sydneylon))
cbdDistance = pd.Series(distance_cbd)
sydData["distance_from_cbd"] = cbdDistance.values

# %%
converted_points = []
for x in range(0, len(sydData)):
    lat = sydData["latitude"].iloc[x]
    lon = sydData["longitude"].iloc[x]
    converted_points.append(convertGeometry(lat, lon))
simple_points = map(lambda x: converted_points[x], range(0, len(sydData), 5))
Ordinates = pd.Series(converted_points)
Ordinates2 = pd.Series(simple_points)
sydData["geometry"] = Ordinates.values
new_list = pd.DataFrame(columns=['test'])
new_list["simplified"] = Ordinates2.values
new_list.head()
# Out:
#   test                                    simplified
# 0  NaN  POINT (151.2868772649104 -33.68082034870997)
# 1  NaN  POINT (151.2881815168596 -33.68341223549853)
# 2  NaN   POINT (151.300566528113 -33.68323809543292)
# 3  NaN   POINT (151.308572129667 -33.69851769406957)
# 4  NaN  POINT (151.2918715655129 -33.68833678920286)

# %%
listtogeo = new_list
limited = listtogeo.head(1)
listtogeo = gpd.GeoDataFrame(new_list, geometry='simplified')

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))
world.head()
countries = world[world['name'] == "Australia"]
base = countries.plot(color='green')
red_dot = mlines.Line2D([], [], linestyle='none', color="red", marker='o', markersize=5, label='Sydney CBD')
blue_dot = mlines.Line2D([], [], linestyle='none', color="blue", marker='o', markersize=5, label='Listings')
plt.legend(handles=[red_dot, blue_dot])
listtogeo.plot(ax=base, marker='o', color='blue', markersize=.5)
plt.plot([151.2073], [-33.8708], marker='o', color='red', markersize=5, alpha=1)
plt.ylim([-34.2,-33.5])
plt.xlim([150.8,151.5])
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.title('Listing distribution in Sydney')

# %%
sortbydistance = sydData.sort_values(["distance_from_cbd"], axis=0, ascending=[True])
sortbydistance.index = range(0, len(sortbydistance))
sortbydistance.iloc[-1]
# Out:
# id                                                                     3079446
# name                                       Forgotten Valley Sleeping up to 30
# host_id                                                                6784646
# host_name                                                        Joanne  & Ali
# neighbourhood_group                                                        NaN
# neighbourhood                                                          Hornsby
# latitude                                                              -33.3897
# longitude                                                              150.989
# room_type                                                      Entire home/apt
# price                                                                      399
# minimum_nights                                                               2
# number_of_reviews                                                            6
# ...

# %%
sortbydistance["price"][(sortbydistance["price"] < 1000) & (sortbydistance["room_type"] == "Entire home/apt")].plot(style=".")
sortbydistance["distance_from_cbd"][sortbydistance["room_type"] == "Entire home/apt"].plot(kind="line")
blue_dot = mlines.Line2D([], [], linestyle='none', color="blue", marker='o', markersize=5, label='Listings')
orange_line = mlines.Line2D([], [], linestyle='-', color="orange", label='Distance from CBD')
plt.legend(handles=[orange_line, blue_dot])
plt.title('Distance from CBD vs Rent Costs (Under $1000)')
plt.xlabel('Distance from CBD (Units = m)')
plt.ylabel('Listing Cost per Day (Units = $AUD)')

# %%
sortbydistance["price"][(sortbydistance["price"] < 400) & (sortbydistance["room_type"] == 'Private room')].plot(style=".")
sortbydistance["distance_from_cbd"][sortbydistance["room_type"] == "Entire home/apt"].plot(kind="line")
blue_dot = mlines.Line2D([], [], linestyle='none', color="blue", marker='o', markersize=5, label='Listings')
orange_line = mlines.Line2D([], [], linestyle='-', color="orange", label='Distance from CBD')
plt.legend(handles=[orange_line, blue_dot])
plt.title('Distance from CBD vs Rent Costs (Under $1000)')
plt.xlabel('Distance from CBD (Units = m)')
plt.ylabel('Listing Cost per Day (Units = $AUD)')
